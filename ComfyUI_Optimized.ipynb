# %% [markdown]
# <a href="https://colab.research.google.com/github/sentulookj-dot/Scout-Legend-/blob/main/ComfyUI_Optimized.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⚡ ComfyUI Optimized Colab
#
# ### 🔴 **Brought to you by [AI With Chucky](https://youtube.com/@AIWithChucky)**
# *Subscribe for more AI tutorials, workflows, and optimization tips!*
#
# **Features:**
# - **Cloudflare Only**: Secure and fast external access.
# - **Robust Storage**: Handles Google Drive disconnections automatically.
# - **Smart Downloader**: Supports Checkpoints, Flux/Diffusion Models, Text Encoders, CLIP Vision, LoRAs, etc.
# - **Auto-Manager**: ComfyUI Manager is always installed and up to date.

# %%
#@title 1. Environment Setup & ComfyUI Install
import os
import shutil
import subprocess

# --- Configuration ---
USE_GOOGLE_DRIVE = True  #@param {type:"boolean"}
UPDATE_COMFY_UI = True   #@param {type:"boolean"}
# ---------------------

if USE_GOOGLE_DRIVE:
    from google.colab import drive
    print("[INFO] Mounting Google Drive (Force Remount)...")
    try:
        drive.mount('/content/drive', force_remount=True)
        WORKSPACE = "/content/drive/MyDrive/ComfyUI"
    except Exception as e:
        print(f"❌ [ERROR] Failed to mount Drive: {e}")
        print("Please restart the runtime: Runtime > Disconnect and Delete Runtime")
        raise
else:
    WORKSPACE = "/content/ComfyUI"

print(f"[INFO] Workspace set to: {WORKSPACE}")

# 1. Install/Update ComfyUI
if not os.path.exists(WORKSPACE):
    print("[INFO] Installing ComfyUI...")
    # !git clone https://github.com/comfyanonymous/ComfyUI {WORKSPACE}
else:
    if UPDATE_COMFY_UI:
        print("[INFO] Updating ComfyUI...")
        # Fix for previous crash: Remove git lock file if it exists
        lock_file = os.path.join(WORKSPACE, ".git", "index.lock")
        if os.path.exists(lock_file):
            print("[WARN] Found git lock file from previous crash. Removing...")
            os.remove(lock_file)

        try:
            # Check if directory is actually readable
            os.listdir(WORKSPACE)
            # !cd {WORKSPACE} && git pull
        except OSError:
            print("❌ [ERROR] Google Drive is disconnected. Please restart Runtime.")

# 2. Install Dependencies
print("[INFO] Installing Dependencies...")
# Check if requirements file exists to confirm we are in the right place
if os.path.exists(os.path.join(WORKSPACE, "requirements.txt")):
    # !cd {WORKSPACE} && pip install xformers!=0.0.18 -r requirements.txt --extra-index-url https://download.pytorch.org/whl/cu121
else:
    print(f"❌ [ERROR] requirements.txt not found in {WORKSPACE}. The drive might still be disconnected.")

print("\n[DONE] Environment Setup Complete.")
# Out:
# [INFO] Mounting Google Drive (Force Remount)...
# Mounted at /content/drive
# [INFO] Workspace set to: /content/drive/MyDrive/ComfyUI
# [INFO] Updating ComfyUI...
# Updating ea33b154..efa6c8f8
# error: Your local changes to the following files would be overwritten by merge:
# 	comfy_extras/nodes_sparse_attention.py
# Please commit your changes or stash them before you merge.
# Aborting
# [INFO] Installing Dependencies...
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# Collecting xformers!=0.0.18
#   Downloading xformers-0.0.35-py39-none-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Collecting comfyui-frontend-package==1.51.9 (from -r requirements.txt (line 1))
#   Downloading comfyui_frontend_package-1.51.9-py3-none-any.whl.metadata (117 bytes)
# Collecting comfyui-workflow-templates==0.11.55 (from -r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates-0.11.55-py3-none-any.whl.metadata (24 kB)
# Collecting comfyui-embedded-docs==0.5.11 (from -r requirements.txt (line 3))
#   Downloading comfyui_embedded_docs-0.5.11-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 4)) (2.11.0+cpu)
# Collecting torchsde (from -r requirements.txt (line 5))
#   Downloading torchsde-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 6)) (0.26.0+cpu)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 7)) (2.11.0+cpu)
# Requirement already satisfied: numpy>=1.25.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 8)) (2.1.3)
# Requirement already satisfied: einops in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 9)) (0.8.2)
# Requirement already satisfied: transformers>=4.50.3 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 10)) (5.16.1)
# Requirement already satisfied: tokenizers>=0.13.3 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 11)) (0.23.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: safetensors>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 13)) (0.8.0)
# Requirement already satisfied: aiohttp>=3.11.8 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 14)) (3.14.3)
# Requirement already satisfied: yarl>=1.18.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 15)) (1.24.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 16)) (6.0.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 17)) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 18)) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 19)) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 20)) (5.9.5)
# Collecting alembic (from -r requirements.txt (line 21))
#   Downloading alembic-1.19.2-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: SQLAlchemy>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 22)) (2.0.52)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 23)) (3.32.4)
# Collecting av>=17.0.0 (from -r requirements.txt (line 24))
#   Downloading av-18.1.0-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Collecting comfy-kitchen==0.2.33 (from -r requirements.txt (line 25))
#   Downloading comfy_kitchen-0.2.33-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (15 kB)
# Collecting comfy-aimdo==0.5.2 (from -r requirements.txt (line 26))
#   Downloading comfy_aimdo-0.5.2-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 27)) (2.32.4)
# Collecting simpleeval>=1.0.0 (from -r requirements.txt (line 28))
#   Downloading simpleeval-1.0.7-py3-none-any.whl.metadata (20 kB)
# Collecting blake3 (from -r requirements.txt (line 29))
#   Downloading blake3-1.0.9-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting kornia>=0.7.1 (from -r requirements.txt (line 32))
#   Downloading kornia-0.8.3-py3-none-any.whl.metadata (22 kB)
# Collecting spandrel (from -r requirements.txt (line 33))
#   Downloading spandrel-0.4.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 34)) (2.13.4)
# Collecting pydantic-settings~=2.0 (from -r requirements.txt (line 35))
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: PyOpenGL>=3.1.8 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 36)) (3.1.10)
# Collecting comfy-angle (from -r requirements.txt (line 37))
#   Downloading comfy_angle-0.1.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Collecting comfyui-workflow-templates-core==0.3.333 (from comfyui-workflow-templates==0.11.55->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_core-0.3.333-py3-none-any.whl.metadata (260 bytes)
# Collecting comfyui-workflow-templates-json==0.1.68 (from comfyui-workflow-templates==0.11.55->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_json-0.1.68-py3-none-any.whl.metadata (265 bytes)
# Collecting comfyui-workflow-templates-media-api==0.3.84 (from comfyui-workflow-templates==0.11.55->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_api-0.3.84-py3-none-any.whl.metadata (290 bytes)
# Collecting comfyui-workflow-templates-media-video==0.3.101 (from comfyui-workflow-templates==0.11.55->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_video-0.3.101-py3-none-any.whl.metadata (283 bytes)
# Collecting comfyui-workflow-templates-media-image==0.3.160 (from comfyui-workflow-templates==0.11.55->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_image-0.3.160-py3-none-any.whl.metadata (283 bytes)
# Collecting comfyui-workflow-templates-media-other==0.3.229 (from comfyui-workflow-templates==0.11.55->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_other-0.3.229-py3-none-any.whl.metadata (306 bytes)
# Collecting comfyui-workflow-templates-media-assets-01==0.1.39 (from comfyui-workflow-templates==0.11.55->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_assets_01-0.1.39-py3-none-any.whl.metadata (290 bytes)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 4)) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 4)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 4)) (2025.3.0)
# Collecting trampoline>=0.1.2 (from torchsde->-r requirements.txt (line 5))
#   Downloading trampoline-0.1.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.13/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (1.28.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (26.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.13/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (2025.11.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.13/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (0.27.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (0.5.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.13/dist-packages (from yarl>=1.18.0->-r requirements.txt (line 15)) (3.19)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic->-r requirements.txt (line 21)) (1.1.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from SQLAlchemy>=2.0.0->-r requirements.txt (line 22)) (3.5.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->-r requirements.txt (line 27)) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->-r requirements.txt (line 27)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->-r requirements.txt (line 27)) (2026.7.22)
# Collecting kornia-rs>=0.1.9 (from kornia>=0.7.1->-r requirements.txt (line 32))
#   Downloading kornia_rs-0.1.14-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (0.4.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings~=2.0->-r requirements.txt (line 35)) (1.2.3)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.28.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers>=4.50.3->-r requirements.txt (line 10)) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers>=4.50.3->-r requirements.txt (line 10)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer->transformers>=4.50.3->-r requirements.txt (line 10)) (0.0.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers>=4.50.3->-r requirements.txt (line 10)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers>=4.50.3->-r requirements.txt (line 10)) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers>=4.50.3->-r requirements.txt (line 10)) (0.1.2)
# Downloading comfyui_frontend_package-1.51.9-py3-none-any.whl (22.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 70.3 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates-0.11.55-py3-none-any.whl (10 kB)
# Downloading comfyui_embedded_docs-0.5.11-py3-none-any.whl (17.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.8/17.8 MB 85.6 MB/s eta 0:00:00
# Downloading comfy_kitchen-0.2.33-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (66.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.1/66.1 MB 9.1 MB/s eta 0:00:00
# Downloading comfy_aimdo-0.5.2-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (428 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 429.0/429.0 kB 19.9 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_core-0.3.333-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.1 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_json-0.1.68-py3-none-any.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 84.7 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_api-0.3.84-py3-none-any.whl (100.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 7.8 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_assets_01-0.1.39-py3-none-any.whl (82.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 MB 9.2 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_image-0.3.160-py3-none-any.whl (89.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 MB 8.9 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_other-0.3.229-py3-none-any.whl (89.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 MB 8.9 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_video-0.3.101-py3-none-any.whl (104.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 7.0 MB/s eta 0:00:00
# Downloading xformers-0.0.35-py39-none-manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 34.5 MB/s eta 0:00:00
# Downloading torchsde-0.2.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 4.2 MB/s eta 0:00:00
# Downloading alembic-1.19.2-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.4/267.4 kB 12.3 MB/s eta 0:00:00
# Downloading av-18.1.0-cp311-abi3-manylinux_2_28_x86_64.whl (35.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.8/35.8 MB 11.9 MB/s eta 0:00:00
# Downloading simpleeval-1.0.7-py3-none-any.whl (18 kB)
# Downloading blake3-1.0.9-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 17.4 MB/s eta 0:00:00
# Downloading kornia-0.8.3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.4 MB/s eta 0:00:00
# Downloading spandrel-0.4.2-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.8/320.8 kB 16.1 MB/s eta 0:00:00
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 3.0 MB/s eta 0:00:00
# Downloading comfy_angle-0.1.1-py3-none-manylinux_2_28_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 27.6 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.14-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 25.5 MB/s eta 0:00:00
# Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Installing collected packages: trampoline, simpleeval, kornia-rs, comfyui-workflow-templates-media-video, comfyui-workflow-templates-media-other, comfyui-workflow-templates-media-image, comfyui-workflow-templates-media-assets-01, comfyui-workflow-templates-media-api, comfyui-workflow-templates-json, comfyui-workflow-templates-core, comfyui-frontend-package, comfyui-embedded-docs, comfy-kitchen, comfy-angle, comfy-aimdo, blake3, av, comfyui-workflow-templates, alembic, xformers, torchsde, pydantic-settings, kornia, spandrel
# Successfully installed alembic-1.19.2 av-18.1.0 blake3-1.0.9 comfy-aimdo-0.5.2 comfy-angle-0.1.1 comfy-kitchen-0.2.33 comfyui-embedded-docs-0.5.11 comfyui-frontend-package-1.51.9 comfyui-workflow-templates-0.11.55 comfyui-workflow-templates-core-0.3.333 comfyui-workflow-templates-json-0.1.68 comfyui-workflow-templates-media-api-0.3.84 comfyui-workflow-templates-media-assets-01-0.1.39 comfyui-workflow-templates-media-image-0.3.160 comfyui-workflow-templates-media-other-0.3.229 comfyui-workflow-templates-media-video-0.3.101 kornia-0.8.3 kornia-rs-0.1.14 pydantic-settings-2.15.0 simpleeval-1.0.7 spandrel-0.4.2 torchsde-0.2.6 trampoline-0.1.2 xformers-0.0.35
#
# [DONE] Environment Setup Complete.

# %%
#@title 2. Install ComfyUI Manager
import os

# Ensure WORKSPACE is defined
if 'WORKSPACE' not in locals():
    WORKSPACE = "/content/drive/MyDrive/ComfyUI" if os.path.exists("/content/drive/MyDrive/ComfyUI") else "/content/ComfyUI"

MANAGER_PATH = os.path.join(WORKSPACE, "custom_nodes", "ComfyUI-Manager")

# Ensure custom_nodes directory exists
os.makedirs(os.path.dirname(MANAGER_PATH), exist_ok=True)

print(f"[INFO] Checking ComfyUI Manager at: {MANAGER_PATH}")

if os.path.exists(MANAGER_PATH):
    print("[INFO] Manager found. Checking for updates...")
    # !cd {MANAGER_PATH} && git pull
else:
    print("[INFO] Manager not found. Cloning repository...")
    # !git clone https://github.com/ltdrdata/ComfyUI-Manager.git {MANAGER_PATH}

# Verification Step
init_file = os.path.join(MANAGER_PATH, "__init__.py")
if os.path.exists(init_file):
    print("\n✅ [SUCCESS] ComfyUI Manager installed and verified successfully.")
else:
    # Loud Fail
    raise Exception("❌ [ERROR] ComfyUI Manager installation failed! Required files are missing.")
# Out:
# [INFO] Checking ComfyUI Manager at: /content/ComfyUI/custom_nodes/ComfyUI-Manager
# [INFO] Manager not found. Cloning repository...
# Cloning into '/content/ComfyUI/custom_nodes/ComfyUI-Manager'...
# remote: Enumerating objects: 32252, done.
# remote: Counting objects: 100% (752/752), done.
# remote: Compressing objects: 100% (353/353), done.
# remote: Total 32252 (delta 590), reused 399 (delta 399), pack-reused 31500 (from 4)
# Receiving objects: 100% (32252/32252), 179.43 MiB | 26.21 MiB/s, done.
# Resolving deltas: 100% (23917/23917), done.
#
# ✅ [SUCCESS] ComfyUI Manager installed and verified successfully.

# %%
#@title 3. Smart Model Downloader
#@markdown Paste direct download links below. This supports **Checkpoints, Diffusion Models (Flux/UNET), Text Encoders (CLIP/T5), CLIP Vision, VAEs, LoRAs, and ControlNets**.

import os
import requests
from tqdm.notebook import tqdm
from urllib.parse import urlparse, unquote
import re

# Ensure WORKSPACE is defined
if 'WORKSPACE' not in locals():
    WORKSPACE = "/content/drive/MyDrive/ComfyUI" if os.path.exists("/content/drive/MyDrive/ComfyUI") else "/content/ComfyUI"

# --- Input Fields ---
CHECKPOINT_URLS = "" #@param {type:"string"}
UNET_DIFFUSION_URLS = "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/blob/main/split_files/diffusion_models/wan2.1_flf2v_720p_14B_fp16.safetensors , https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/blob/main/split_files/diffusion_models/wan2.1_fun_control_1.3B_bf16.safetensors , https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/blob/main/split_files/diffusion_models/wan2.1_fun_camera_v1.1_1.3B_bf16.safetensors" #@param {type:"string"}
TEXT_ENCODER_URLS = "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/blob/main/split_files/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors" #@param {type:"string"}
CLIP_VISION_URLS = "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/blob/main/split_files/clip_vision/clip_vision_h.safetensors" #@param {type:"string"}
VAE_URLS = "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/blob/main/split_files/vae/wan_2.1_vae.safetensors" #@param {type:"string"}
LORA_URLS = "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/blob/main/split_files/loras/wan_alpha_2.1_rgba_lora.safetensors" #@param {type:"string"}
CONTROLNET_URLS = "" #@param {type:"string"}
EMBEDDING_URLS = "" #@param {type:"string"}

# --- Directory Mapping ---
DIRS = {
    "checkpoints":      os.path.join(WORKSPACE, "models/checkpoints"),
    "diffusion_models": os.path.join(WORKSPACE, "models/diffusion_models"),
    "clip":             os.path.join(WORKSPACE, "models/clip"),
    "clip_vision":      os.path.join(WORKSPACE, "models/clip_vision"),
    "vae":              os.path.join(WORKSPACE, "models/vae"),
    "loras":            os.path.join(WORKSPACE, "models/loras"),
    "controlnet":       os.path.join(WORKSPACE, "models/controlnet"),
    "embeddings":       os.path.join(WORKSPACE, "models/embeddings")
}

for key, d in DIRS.items():
    os.makedirs(d, exist_ok=True)

def get_filename_from_headers(response, url):
    """Extract filename from Content-Disposition header or fallback to URL."""
    # 1. Try Content-Disposition
    if "Content-Disposition" in response.headers:
        cd = response.headers["Content-Disposition"]
        # Extract filename="example.safetensors"
        fnames = re.findall('filename="?([^"]+)"?', cd)
        if fnames:
            return fnames[0]

    # 2. Fallback to URL path
    parsed_url = urlparse(url)
    filename = unquote(os.path.basename(parsed_url.path))

    # 3. Last resort
    if not filename:
        return "downloaded_file.safetensors"

    return filename

def download_file_modern(url, target_dir):
    try:
        # Stream GET to catch headers before downloading
        response = requests.get(url, stream=True, allow_redirects=True)
        response.raise_for_status()

        filename = get_filename_from_headers(response, url)
        file_path = os.path.join(target_dir, filename)

        # Check if file exists
        if os.path.exists(file_path):
            # Optional: Check size if you wanted strictly smart resume, but simple skip is safer for Colab
            print(f"   ⏩ Skipping (Exists): {filename}")
            return

        total_size = int(response.headers.get('content-length', 0))
        block_size = 1024 * 1024 # 1MB chunks

        print(f"   ⬇️ Downloading: {filename}")

        # Modern Progress Bar
        with tqdm(total=total_size, unit='iB', unit_scale=True, desc=filename, leave=False) as bar:
            with open(file_path, 'wb') as f:
                for data in response.iter_content(block_size):
                    bar.update(len(data))
                    f.write(data)

        print(f"   ✅ Downloaded: {filename}")

    except Exception as e:
        print(f"   ❌ Failed: {url} | Error: {e}")

def process_category(urls_str, target_dir, category_name):
    if not urls_str.strip():
        return

    url_list = [u.strip() for u in urls_str.replace(',', '\n').split('\n') if u.strip()]
    print(f"\n📂 [{category_name}] Processing {len(url_list)} files...")

    for url in url_list:
        download_file_modern(url, target_dir)

# --- Execute Downloads ---
process_category(CHECKPOINT_URLS,      DIRS["checkpoints"],      "Checkpoints")
process_category(UNET_DIFFUSION_URLS,  DIRS["diffusion_models"], "Diffusion Models (UNET/Flux)")
process_category(TEXT_ENCODER_URLS,    DIRS["clip"],             "Text Encoders (CLIP/T5)")
process_category(CLIP_VISION_URLS,     DIRS["clip_vision"],      "CLIP Vision")
process_category(VAE_URLS,             DIRS["vae"],              "VAE")
process_category(LORA_URLS,            DIRS["loras"],            "LoRA")
process_category(CONTROLNET_URLS,      DIRS["controlnet"],       "ControlNet")
process_category(EMBEDDING_URLS,       DIRS["embeddings"],       "Embeddings")

print("\n✅ [DONE] All downloads finished.")
# Out:
# 📂 [Diffusion Models (UNET/Flux)] Processing 3 files...
#    ⬇️ Downloading: wan2.1_flf2v_720p_14B_fp16.safetensors
# wan2.1_flf2v_720p_14B_fp16.safetensors: 0.00iB [00:00, ?iB/s]
#    ✅ Downloaded: wan2.1_flf2v_720p_14B_fp16.safetensors
#    ⬇️ Downloading: wan2.1_fun_control_1.3B_bf16.safetensors
# wan2.1_fun_control_1.3B_bf16.safetensors: 0.00iB [00:00, ?iB/s]
#    ✅ Downloaded: wan2.1_fun_control_1.3B_bf16.safetensors
#    ⬇️ Downloading: wan2.1_fun_camera_v1.1_1.3B_bf16.safetensors
# wan2.1_fun_camera_v1.1_1.3B_bf16.safetensors: 0.00iB [00:00, ?iB/s]
#    ✅ Downloaded: wan2.1_fun_camera_v1.1_1.3B_bf16.safetensors
#
# 📂 [Text Encoders (CLIP/T5)] Processing 1 files...
#    ⬇️ Downloading: umt5_xxl_fp8_e4m3fn_scaled.safetensors
# umt5_xxl_fp8_e4m3fn_scaled.safetensors: 0.00iB [00:00, ?iB/s]
#    ✅ Downloaded: umt5_xxl_fp8_e4m3fn_scaled.safetensors
#
# 📂 [CLIP Vision] Processing 1 files...
#    ⬇️ Downloading: clip_vision_h.safetensors
# clip_vision_h.safetensors: 0.00iB [00:00, ?iB/s]
#    ✅ Downloaded: clip_vision_h.safetensors
#
# 📂 [VAE] Processing 1 files...
#    ⬇️ Downloading: wan_2.1_vae.safetensors
# wan_2.1_vae.safetensors: 0.00iB [00:00, ?iB/s]
#    ✅ Downloaded: wan_2.1_vae.safetensors
#
# 📂 [LoRA] Processing 1 files...
#    ⬇️ Downloading: wan_alpha_2.1_rgba_lora.safetensors
# wan_alpha_2.1_rgba_lora.safetensors: 0.00iB [00:00, ?iB/s]
#    ✅ Downloaded: wan_alpha_2.1_rgba_lora.safetensors
#
# ✅ [DONE] All downloads finished.

# %%
# @title 4. NO Disconnect
# %%html
<b>🔊 Keep-Alive Audio Player</b><br>
<audio src="https://raw.githubusercontent.com/anars/blank-audio/master/10-minutes-of-silence.mp3" autoplay loop controls style="width: 300px;" />
<br><small>Running this silent audio loop prevents the browser from throttling the connection when you switch tabs.</small>
# Out:
# <b>🔊 Keep-Alive Audio Player</b><br>
# <audio src="https://raw.githubusercontent.com/anars/blank-audio/master/10-minutes-of-silence.mp3" autoplay loop controls style="width: 300px;" />
# <br><small>Running this silent audio loop prevents the browser from throttling the connection when you switch tabs.</small>

# %%
#@title 5. Run ComfyUI (Cloudflare)
import subprocess
import threading
import time
import socket
import os

# Ensure WORKSPACE is defined
if 'WORKSPACE' not in locals():
    WORKSPACE = "/content/drive/MyDrive/ComfyUI" if os.path.exists("/content/drive/MyDrive/ComfyUI") else "/content/ComfyUI"

# 1. Install Cloudflared
print("[INFO] Setting up Cloudflare Tunnel...")
# !wget -q -nc https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

# 2. Define Tunnel Logic
def start_tunnel(port):
    # Wait for ComfyUI to start listening
    while True:
        time.sleep(1)
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        result = sock.connect_ex(('127.0.0.1', port))
        if result == 0:
            break
        sock.close()

    print("\n[INFO] ComfyUI detected. Launching Tunnel...\n")

    # Start Cloudflare Tunnel
    p = subprocess.Popen(["cloudflared", "tunnel", "--url", f"http://127.0.0.1:{port}"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Parse Output for URL
    for line in p.stderr:
        l = line.decode()
        if "trycloudflare.com" in l:
            url = l[l.find("http"):].strip()
            print("\n" + "="*60)
            print(f"🚀 PUBLIC URL: {url}")
            print("="*60 + "\n")

# 3. Start Tunnel Thread
threading.Thread(target=start_tunnel, daemon=True, args=(8188,)).start()

# 4. Run ComfyUI
# Check if main.py exists in workspace
if os.path.exists(os.path.join(WORKSPACE, "main.py")):
    # %cd {WORKSPACE}
    print("[INFO] Booting ComfyUI... (Wait for the URL to appear)")
    # !python main.py --dont-print-server --listen 127.0.0.1 --port 8188
else:
    print(f"❌ [ERROR] Could not find main.py in {WORKSPACE}. Did the drive disconnect?")
# Out:
# [INFO] Setting up Cloudflare Tunnel...
# (Reading database ... 118423 files and directories currently installed.)
# Preparing to unpack cloudflared-linux-amd64.deb ...
# Unpacking cloudflared (2026.8.3) over (2026.8.3) ...
# Setting up cloudflared (2026.8.3) ...
# Processing triggers for man-db (2.10.2-1) ...
# /content/drive/MyDrive/ComfyUI
# [INFO] Booting ComfyUI... (Wait for the URL to appear)
# [INFO] setup plugin alembic.autogenerate.schemas
# [INFO] setup plugin alembic.autogenerate.tables
# [INFO] setup plugin alembic.autogenerate.types
# [INFO] setup plugin alembic.autogenerate.constraints
# [INFO] setup plugin alembic.autogenerate.defaults
# [INFO] setup plugin alembic.autogenerate.comments
# [INFO] setup plugin alembic.ext.checkconstraint_byname
# [WARNING] Could not autodetect AIMDO implementation, assuming Nvidia
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-09-08 08:07:13.446
# ** Platform: Linux
# ** Python version: 3.13.15 (main, Aug  6 2026, 11:06:23) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/drive/MyDrive/ComfyUI
# ** ComfyUI Base Folder Path: /content/drive/MyDrive/ComfyUI
# ** User directory: /content/drive/MyDrive/ComfyUI/user
# ** ComfyUI-Manager config path: /content/drive/MyDrive/ComfyUI/user/__manager/config.ini
# ** Log path: /content/drive/MyDrive/ComfyUI/user/comfyui.log
# [INFO]
# Prestartup times for custom nodes:
# [INFO]    7.4 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
# [INFO]
# [INFO] Found comfy_kitchen backend eager: {'available': True, 'disabled': False, 'unavailable_reason': None, 'capabilities': ['adaln', 'apply_rope', 'apply_rope1', 'apply_rope1_', 'apply_rope_', 'apply_rope_split_half', 'apply_rope_split_half1', 'apply_rope_split_half1_', 'apply_rope_split_half_', 'convrot_w4a4_linear', 'dequantize_convrot_w4a4_weight', 'dequantize_int8_convrot_weight', 'dequantize_int8_convrot_weight_dtype', 'dequantize_int8_embedding', 'dequantize_int8_simple', 'dequantize_int8_simple_dtype', 'dequantize_mxfp8', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'dequantize_w4a8_int8_weight', 'gemv_awq_w4a16', 'int8_linear', 'na3d', 'prepare_int4_weight_for_int8_linear', 'quantize_and_rotate_rowwise', 'quantize_convrot_w4a4_weight', 'quantize_int8_convrot_weight', 'quantize_int8_rowwise', 'quantize_int8_tensorwise', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'quantize_svdquant_w4a4', 'quantize_w4a8_int8_weight', 'rms_adaln', 'rms_rope', 'rms_rope1', 'rms_rope1_', 'rms_rope_', 'rms_rope_split_half', 'rms_rope_split_half1', 'rms_rope_split_half1_', 'rms_rope_split_half_', 'rotate_int8_convrot_weight', 'scaled_mm_mxfp8', 'scaled_mm_nvfp4', 'scaled_mm_svdquant_w4a4', 'sol_attn', 'stochastic_rounding_fp8', 'w4a8_int8_linear']}
# [INFO] Found comfy_kitchen backend hip: {'available': False, 'disabled': False, 'unavailable_reason': 'PyTorch ROCm/HIP runtime not available', 'capabilities': []}
# [INFO] Found comfy_kitchen backend triton: {'available': False, 'disabled': True, 'unavailable_reason': "ImportError: No module named 'triton'", 'capabilities': []}
# [INFO] Found comfy_kitchen backend cuda: {'available': False, 'disabled': True, 'unavailable_reason': 'CUDA not available on this system', 'capabilities': []}
# [INFO] Checkpoint files will always be loaded safely.
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/main.py", line 251, in <module>
#     import execution
#   File "/content/drive/MyDrive/ComfyUI/execution.py", line 17, in <module>
#     import comfy.model_management
#   File "/content/drive/MyDrive/ComfyUI/comfy/model_management.py", line 364, in <module>
#     total_vram = get_total_memory(get_torch_device()) / (1024 * 1024)
#                                   ~~~~~~~~~~~~~~~~^^
#   File "/content/drive/MyDrive/ComfyUI/comfy/model_management.py", line 213, in get_torch_device
#     return torch.device(torch.cuda.current_device())
#                         ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/cuda/__init__.py", line 1148, in current_device
#     _lazy_init()
#     ~~~~~~~~~~^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/cuda/__init__.py", line 471, in _lazy_init
#     raise AssertionError("Torch not compiled with CUDA enabled")
# AssertionError: Torch not compiled with CUDA enabled
